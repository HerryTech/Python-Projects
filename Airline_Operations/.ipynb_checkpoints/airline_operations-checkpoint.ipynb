# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Load Data

# %%
flights = pd.read_csv("Dataset/CSV/flights.csv")
airlines = pd.read_csv("Dataset/CSV/airlines.csv")
airports = pd.read_csv("Dataset/CSV/airports.csv")

# %% [markdown]
# #### Check Shape

# %%
flights.shape, airlines.shape, airports.shape
# Out:
# ((1048575, 31), (14, 2), (322, 7))

# %% [markdown]
# #### View First Rows

# %%
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                  NaN               NaN
# 1           -9.0         0          0                  NaN               NaN
# 2            5.0         0          0                  NaN               NaN
# 3           -9.0         0          0                  NaN               NaN
# 4          -21.0         0          0                  NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
# [5 rows x 31 columns]

# %%
airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %% [markdown]
# #### Check Column Names

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
airlines.columns
# Out:
# Index(['IATA_CODE', 'AIRLINE'], dtype='object')

# %%
airports.columns
# Out:
# Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')

# %% [markdown]
# #### Check Data Types

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 31 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   YEAR                 1048575 non-null  int64
#  1   MONTH                1048575 non-null  int64
#  2   DAY                  1048575 non-null  int64
#  3   DAY_OF_WEEK          1048575 non-null  int64
#  4   AIRLINE              1048575 non-null  object
#  5   FLIGHT_NUMBER        1048575 non-null  int64
#  6   TAIL_NUMBER          1040825 non-null  object
#  7   ORIGIN_AIRPORT       1048575 non-null  object
#  8   DESTINATION_AIRPORT  1048575 non-null  object
#  9   SCHEDULED_DEPARTURE  1048575 non-null  int64
#  10  DEPARTURE_TIME       1009060 non-null  float64
#  11  DEPARTURE_DELAY      1009060 non-null  float64
#  12  TAXI_OUT             1008346 non-null  float64
#  13  WHEELS_OFF           1008346 non-null  float64
#  14  SCHEDULED_TIME       1048573 non-null  float64
#  15  ELAPSED_TIME         1005504 non-null  float64
#  16  AIR_TIME             1005504 non-null  float64
#  17  DISTANCE             1048575 non-null  int64
#  18  WHEELS_ON            1007279 non-null  float64
#  19  TAXI_IN              1007279 non-null  float64
#  20  SCHEDULED_ARRIVAL    1048575 non-null  int64
#  21  ARRIVAL_TIME         1007279 non-null  float64
#  22  ARRIVAL_DELAY        1005504 non-null  float64
#  23  DIVERTED             1048575 non-null  int64
#  24  CANCELLED            1048575 non-null  int64
#  25  CANCELLATION_REASON  40527 non-null    object
#  26  AIR_SYSTEM_DELAY     228528 non-null   float64
#  27  SECURITY_DELAY       228528 non-null   float64
#  28  AIRLINE_DELAY        228528 non-null   float64
#  29  LATE_AIRCRAFT_DELAY  228528 non-null   float64
#  30  WEATHER_DELAY        228528 non-null   float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 248.0+ MB

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  14 non-null     object
#  1   AIRLINE    14 non-null     object
# dtypes: object(2)
# memory usage: 356.0+ bytes

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  322 non-null    object
#  1   AIRPORT    322 non-null    object
#  2   CITY       322 non-null    object
#  3   STATE      322 non-null    object
#  4   COUNTRY    322 non-null    object
#  5   LATITUDE   319 non-null    float64
#  6   LONGITUDE  319 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 17.7+ KB

# %% [markdown]
# #### Check Missing Values

# %%
flights.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER               7750
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           39515
# DEPARTURE_DELAY          39515
# TAXI_OUT                 40229
# WHEELS_OFF               40229
# SCHEDULED_TIME               2
# ELAPSED_TIME             43071
# AIR_TIME                 43071
# DISTANCE                     0
# WHEELS_ON                41296
# TAXI_IN                  41296
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             41296
# ARRIVAL_DELAY            43071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    1008048
# AIR_SYSTEM_DELAY        820047
# SECURITY_DELAY          820047
# AIRLINE_DELAY           820047
# LATE_AIRCRAFT_DELAY     820047
# WEATHER_DELAY           820047
# dtype: int64

# %%
airlines.isnull().sum()
# Out:
# IATA_CODE    0
# AIRLINE      0
# dtype: int64

# %%
airports.isnull().sum()
# Out:
# IATA_CODE    0
# AIRPORT      0
# CITY         0
# STATE        0
# COUNTRY      0
# LATITUDE     3
# LONGITUDE    3
# dtype: int64

# %% [markdown]
# #### Why CANCELLATION REASON has missing values

# %%
flights['CANCELLED'].value_counts()
# Out:
# CANCELLED
# 0    1008048
# 1      40527
# Name: count, dtype: int64

# %% [markdown]
# - Because flights that were not cancelled should not have a cancellation reason.
# - These missing values are meaningful.
# - Therefore, can't be filled or removed.

# %% [markdown]
# #### Why AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY have missing values

# %% [markdown]
# - AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY are often only populated when a flight experienced a reportable delay.
# - Most flights either arrived on time, arrived early or had minor delays
# - Therefore no official delay cause was recorded

# %% [markdown]
# #### Why DEPARTURE_TIME, DEPARTURE_DELAY, TAXI_OUT, WHEELS_OFF, ARRIVAL_TIME, ARRIVAL_DELAY, AIR_TIME, ELAPSED_TIME have missing values

# %% [markdown]
# - These numbers are suspiciously close to CANCELLATION_REASON non-null count of 40,527
#
# - This suggests that many of these missing values belong to cancelled flights.
# - Which is completely logical. A cancelled flight never departed, taxied, landed or accumulated air time

# %% [markdown]
# #### Data Understanding Summary

# %% [markdown]
# - The dataset consists of one primary flight operations table containing over 1 million flight records and two supporting lookup tables for airlines and airports. Initial inspection indicates that most missing values are business related rather than data quality issues. Missing operational fields are likely associated with cancelled flights, while missing delay cause fields appear to occur when flights did not experience reportable delays. The airlines table is fully complete, and the airports table contains only minor geographic data gaps. Overall, the dataset appears suitable for operational performance analysis with no major structural issues identified at this stage.

# %% [markdown]
# #### Check Duplicates

# %%
flights.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Investigate Delays

# %%
flights['DEPARTURE_DELAY'].describe()
# Out:
# count    1.009060e+06
# mean     1.133485e+01
# std      3.922372e+01
# min     -6.100000e+01
# 25%     -5.000000e+00
# 50%     -1.000000e+00
# 75%      1.100000e+01
# max      1.988000e+03
# Name: DEPARTURE_DELAY, dtype: float64

# %%
flights['ARRIVAL_DELAY'].describe()
# Out:
# count    1.005504e+06
# mean     7.612191e+00
# std      4.209367e+01
# min     -8.200000e+01
# 25%     -1.200000e+01
# 50%     -3.000000e+00
# 75%      1.200000e+01
# max      1.971000e+03
# Name: ARRIVAL_DELAY, dtype: float64

# %%
flights[['DEPARTURE_DELAY', 'ARRIVAL_DELAY']].hist(figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'DEPARTURE_DELAY'}>,
#         <Axes: title={'center': 'ARRIVAL_DELAY'}>]], dtype=object)

# %% [markdown]
# ###### Interpretation of Departure Delay Distribution
#
# The departure delay distribution is heavily right skewed, meaning that most flights experienced little to no departure delay, while a relatively small number of flights experienced very large delays. This is evident from both the histogram and the summary statistics. The median departure delay is -1 minute, indicating that at least half of the flights departed on time or slightly early. The mean departure delay is 11.33 minutes, which is much higher than the median because a small number of extremely delayed flights pull the average upward. The minimum delay of -61 minutes shows that some flights departed significantly earlier than scheduled, while the maximum delay of 1,988 minutes demonstrates the presence of rare but severe operational disruptions. Overall, the distribution suggests that large departure delays are uncommon, but when they occur, they can be substantial enough to significantly affect the overall average.

# %% [markdown]
# ##### Interpretation of Arrival Delay Distribution
#
# The arrival delay distribution also exhibits a strong right skew. Most flights arrived close to schedule, with many arriving early or only slightly late. This can be seen from the median arrival delay of -3 minutes, indicating that more than half of flights arrived on time or earlier than scheduled. The mean arrival delay of 7.61 minutes is higher than the median due to the influence of a relatively small number of flights with very large delays. The minimum arrival delay of -82 minutes indicates that some flights arrived considerably earlier than scheduled, while the maximum delay of 1,971 minutes highlights the occurrence of rare but extreme disruptions. Similar to departure delays, the majority of flights cluster around zero delay, while a small number of severely delayed flights create a long right tail in the distribution.

# %%
flights['AIRLINE'].value_counts()
# Out:
# AIRLINE
# WN    221586
# DL    147486
# EV    111206
# OO    107099
# AA     97549
# UA     87606
# US     73942
# MQ     65513
# B6     48157
# AS     29614
# NK     19612
# F9     14669
# HA     14133
# VX     10403
# Name: count, dtype: int64

# %%
flights['ORIGIN_AIRPORT'].nunique()
# Out:
# 315

# %%
flights['DESTINATION_AIRPORT'].nunique()
# Out:
# 315

# %%
flights['YEAR'].value_counts()
# Out:
# YEAR
# 2015    1048575
# Name: count, dtype: int64

# %% [markdown]
# - The dataset contains over one million flight records from 14 airlines operating across 315 airports during 2015.

# %% [markdown]
# #### Create Working Copy

# %%
df = flights.copy()

# %% [markdown]
# #### EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### How many flights were delayed?

# %%
(df['DEPARTURE_DELAY'] > 0).sum()
# Out:
# 417074

# %%
# Departure delay rate
(df['DEPARTURE_DELAY'] > 0).mean() * 100
# Out:
# 39.77531411677753

# %% [markdown]
# #### How many flights arrived late?

# %%
(df['ARRIVAL_DELAY'] > 0).sum()
# Out:
# 424129

# %%
# Arrival delay rate
(df['ARRIVAL_DELAY'] > 0).mean() * 100
# Out:
# 40.44813198865126

# %% [markdown]
# #### What percentage were cancelled?

# %%
# Cancellation rate
df['CANCELLED'].mean() * 100
# Out:
# 3.8649595880123027

# %%
(df['CANCELLED'] == 1).sum()
# Out:
# 40527

# %% [markdown]
# #### What percentage were diverted?

# %%
# Diversion rate
df["DIVERTED"].mean() * 100
# Out:
# 0.2426149774694228

# %%
(df["DIVERTED"] == 1).sum()
# Out:
# 2544

# %%
summary = pd.DataFrame({
    'Metric': [
        'Departure Delay Rate',
        'Arrival Delay Rate',
        'Cancellation Rate',
        'Diversion Rate'
    ],
    "Count": [
        (df['DEPARTURE_DELAY'] > 0).sum(),
        (df['ARRIVAL_DELAY'] > 0).sum(),
        (df['CANCELLED'] == 1).sum(),
        (df["DIVERTED"] == 1).sum()
    ],
    'Value (%)': [
        (df['DEPARTURE_DELAY'] > 0).mean() * 100,
        (df['ARRIVAL_DELAY'] > 0).mean() * 100,
        df['CANCELLED'].mean() * 100,
        df['DIVERTED'].mean() * 100
    ]
})

summary
# Out:
#                  Metric   Count  Value (%)
# 0  Departure Delay Rate  417074  39.775314
# 1    Arrival Delay Rate  424129  40.448132
# 2     Cancellation Rate   40527   3.864960
# 3        Diversion Rate    2544   0.242615

# %% [markdown]
# #### Business Interpretation
#
# - The airline's operational performance shows a substantial level of disruption. Approximately 40% of all flights experienced departure delays and slightly more than 40% arrived late. This means that roughly four out of every ten flights failed to meet their scheduled departure or arrival times. Such a high proportion of delayed flights is likely to have a significant impact on passenger satisfaction and supports management's concern regarding increasing customer complaints.
#
# - Although cancellations account for only 3.86% of all flights, they represent over 40,000 cancelled flights during the year. From a customer experience perspective, cancellations are often more disruptive than delays because passengers may need to rebook, wait for alternative flights, or abandon travel plans altogether. Therefore, despite being less frequent than delays, cancellations should be considered a critical area of investigation.
#
# - Diversions are relatively rare, affecting only 0.24% of flights. While diversions can create severe disruptions for affected passengers, their low occurrence suggests they are unlikely to be a primary driver of overall customer dissatisfaction across the network.
#
# - Overall, the results indicate that delays, rather than cancellations or diversions, are the dominant operational issue and should be the primary focus of subsequent analysis.

# %%
monthly_delay = (
    df.groupby('MONTH')
      .agg({
          'DEPARTURE_DELAY': 'mean',
          'ARRIVAL_DELAY': 'mean',
          'CANCELLED': 'mean'
      })
      .reset_index()
)

monthly_delay['CANCELLED'] = monthly_delay['CANCELLED'] * 100

monthly_delay
# Out:
#    MONTH  DEPARTURE_DELAY  ARRIVAL_DELAY  CANCELLED
# 0      1         9.759471       5.813583   2.549535
# 1      2        11.885284       8.320500   4.780389
# 2      3        14.843006      11.398621   5.372919

# %%
import matplotlib.pyplot as plt

monthly_delay.plot(
    x='MONTH',
    y=['DEPARTURE_DELAY', 'ARRIVAL_DELAY'],
    figsize=(10,5),
    marker='o'
)

plt.title('Average Monthly Delays')
plt.ylabel('Minutes')
plt.show()

# %%
monthly_delay = (
    df.groupby('MONTH')
      .agg({
          'DEPARTURE_DELAY': 'sum',
          'ARRIVAL_DELAY': 'sum',
          'CANCELLED': 'sum'
      })
      .reset_index()
)

monthly_delay
# Out:
#    MONTH  DEPARTURE_DELAY  ARRIVAL_DELAY  CANCELLED
# 0      1        4472873.0      2656883.0      11982
# 1      2        4862650.0      3391960.0      20517
# 2      3        2102022.0      1605245.0       8028

# %%
import matplotlib.pyplot as plt

monthly_delay.plot(
    x='MONTH',
    y=['DEPARTURE_DELAY', 'ARRIVAL_DELAY'],
    figsize=(10,5),
    marker='o'
)

plt.title('Monthly Delays')
plt.ylabel('Minutes')
plt.show()
